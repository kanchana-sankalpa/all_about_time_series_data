# %%
# -*- coding: utf-8 -*-
"""
PCC of a dataset 

Created on Wed Jan  6 12:57:32 2021

@author: kanchana
"""


import pandas as pd 
#import missingno 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))

df = pd.read_csv(cwd+"/QLD_open_data/combined_buff_burnett.csv" ,index_col=False, header=0) 

del df['TIMESTAMP']

pearsoncorr = df.corr(method='pearson')
print('pearsoncorr shape')
print(pearsoncorr.shape)


fig, ax = plt.subplots(figsize=(25,25))
# Heat map for raw data
sns.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            linewidths=0.1, annot=True, annot_kws={"size":10})


df2 = pd.read_csv(cwd+"/QLD_open_data/combined_buff_burnett_sampled.csv" ,index_col=False, header=0) 

del df2['TIMESTAMP']

pearsoncorr2 = df2.corr(method='pearson')
print('pearsoncorr2 df2 shape')
print(pearsoncorr2.shape)


fig, ax = plt.subplots(figsize=(25,25))
# Heat map for raw data
sns.heatmap(pearsoncorr2, 
            xticklabels=pearsoncorr2.columns,
            yticklabels=pearsoncorr2.columns,
            cmap='RdBu_r',
            linewidths=0.1, annot=True, annot_kws={"size":10})
# Out:
# Files in 'F:\\Github\\all_about_time_series_data': ['.ipynb_checkpoints', 'join_two_datasets.ipynb', 'join_two_datasets_sampled.ipynb', 'PCC.ipynb', 'QLD_open_data', 'sampling.ipynb']
# pearsoncorr shape
# (23, 23)
# pearsoncorr2 df2 shape
# (23, 23)
