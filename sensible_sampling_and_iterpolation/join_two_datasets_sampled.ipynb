# %%
# -*- coding: utf-8 -*-
"""
Join two datasets within a folder

Created on Wed Jan  6 12:13:02 2021

@author: kanchana
"""
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import glob
import matplotlib.dates as mdates


cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))

path = cwd+'/QLD_open_data/sampled' # use your path
all_files = glob.glob(path + "/*.csv")
df = pd.DataFrame() 

for idx, filename in enumerate(all_files):
    if idx == 0:
        print('index 0')
        
        df1 = pd.read_csv(filename, index_col=False, header=0)
        df1.dropna(axis = 0, how ='all', inplace = True)
        
        filename_w_ext = os.path.basename(filename)
        exact_filename, file_extension = os.path.splitext(filename_w_ext)
        print('exact_filename')
        print(exact_filename)
        
        
        print(df1.shape)
        print(df1.dtypes)

        
        df1['TIMESTAMP'] = pd.to_datetime(df1['TIMESTAMP'],  format="%Y-%m-%d %H:%M:%S" , errors='coerce')
        df1 = df1.set_index('TIMESTAMP')
        
        print('df1')
        print(df1.head(10))
        df1.sort_index()
        df=df1
        
    else:
        df2 = pd.read_csv(filename, index_col=False, header=0)
        df2.dropna(axis = 0, how ='all', inplace = True)
        
        filename_w_ext = os.path.basename(filename)
        exact_filename, file_extension = os.path.splitext(filename_w_ext)
        print('exact_filename')
        print(exact_filename)
        
        
        print(df2.shape)
        print(df2.dtypes)

        
        df2['TIMESTAMP'] = pd.to_datetime(df2['TIMESTAMP'],  format="%Y-%m-%d %H:%M:%S" , errors='coerce')
        df2 = df2.set_index('TIMESTAMP')
        
        print('df2')
        print(df2.head(10))
        df2.sort_index()
        
        results = pd.DataFrame()
        
        if(df.shape[0] < df2.shape[0]):
            print('df.shape[0] < df2.shape[0]')
            results = pd.merge(df2.sort_index(), df.sort_index(), on='TIMESTAMP', how='outer')
        else:
            print('--other_condition ---')
            results = pd.merge(df.sort_index(), df2.sort_index(), on='TIMESTAMP', how='outer')
           
        results=results.sort_index()
        print('----results-----')
        print(results.shape)
        df=results
        
print('saving file')
df.to_csv(cwd+'/QLD_open_data/combined_buff_burnett_sampled.csv')
# Out:
# Files in 'F:\\Github\\all_about_time_series_data': ['.ipynb_checkpoints', 'join_two_datasets.ipynb', 'join_two_datasets_sampled.ipynb', 'QLD_open_data', 'sampling.ipynb']
# index 0
# exact_filename
# baffle-quality
# (58499, 16)
# TIMESTAMP               object
# Samp_EXO-TempC         float64
# Samp_EXO-TurbNTU       float64
# Samp_EXO-SpCondmScm    float64
# Samp_EXO-DOPerSat      float64
# Samp_EXO-Salpsu        float64
# Samp_EXO-BatV          float64
# Samp_EXO-DOmgL         float64
# Samp_EXO-ChlugL        float64
# Samp_EXO-pH            float64
# Samp_EXO-pHmV          float64
# Samp_EXO-Depthm        float64
# Samp_EXO-ChlRFU        float64
# Samp_EXO-TurbFNU       float64
# Samp_EXO-fDOMRFU       float64
# 2019-11-28 04:20:00               9.0               3.0               9.0
# 2019-11-28 04:30:00               9.0               3.0               9.0
# 2019-11-28 04:40:00               9.0               3.0               9.0
# 2019-11-28 04:50:00              12.0               3.0               9.0
# 2019-11-28 05:00:00              15.0               3.0               9.0
# 2019-11-28 05:10:00              12.0               3.0               9.0
# 2019-11-28 05:20:00              12.0               3.0               9.0
# 2019-11-28 05:30:00              11.0               3.0               9.0
# 2019-11-28 05:40:00              11.0               3.0               9.0
# 2019-11-28 05:50:00              10.0               3.0               9.0
# exact_filename
# burnett
# (53611, 9)
# TIMESTAMP                 object
# Samp_RECORD              float64
# Samp_Temp_degC           float64
# Samp_EC_uScm             float64
# Samp_pH                  float64
# Samp_DO_Sat              float64
# Samp_DO_mg               float64
# Samp_Turbidity_NTU       float64
# Samp_Chloraphylla_ugL    float64
# dtype: object
# df2
#                        Samp_RECORD  Samp_Temp_degC  Samp_EC_uScm  Samp_pH  \
# TIMESTAMP
# 2019-12-31 00:00:00  108437.000000            27.0  49910.000000      8.0
# 2019-12-31 00:10:00  108437.497911            27.0  49903.568444      8.0
# 2019-12-31 00:20:00  108437.820551            27.0  49894.854755      8.0
# 2019-12-31 00:30:00  108438.000000            27.0  49885.000000      8.0
# 2019-12-31 00:40:00  108438.068338            27.0  49875.145245      8.0
# 2019-12-31 00:50:00  108438.057645            27.0  49866.431556      8.0
# 2019-12-31 01:00:00  108438.000000            27.0  49860.000000      8.0
# 2019-12-31 01:10:00  108437.932441            27.0  49856.591318      8.0
# 2019-12-31 01:20:00  108437.911833            27.0  49855.344947      8.0
# 2019-12-31 01:30:00  108438.000000            27.0  49855.000000      8.0
#
#                      Samp_DO_Sat  Samp_DO_mg  Samp_Turbidity_NTU  \
# TIMESTAMP
# 2019-12-31 00:00:00    97.000000         6.0            6.000000
# 2019-12-31 00:10:00    96.551832         6.0            5.188670
# 2019-12-31 00:20:00    96.619244         6.0            4.906492
# 2019-12-31 00:30:00    97.000000         6.0            5.000000
# 2019-12-31 00:40:00    97.491867         6.0            5.315730
# 2019-12-31 00:50:00    97.892612         6.0            5.700219
# 2019-12-31 01:00:00    98.000000         6.0            6.000000
# 2019-12-31 01:10:00    97.702920         6.0            6.103964
# 2019-12-31 01:20:00    97.254753         6.0            6.070412
# 2019-12-31 01:30:00    97.000000         6.0            6.000000
#
#                      Samp_Chloraphylla_ugL
# TIMESTAMP
# 2019-12-31 00:00:00               6.000000
# 2019-12-31 00:10:00               6.123237
# 2019-12-31 00:20:00               6.098590
# 2019-12-31 00:30:00               6.000000
# 2019-12-31 00:40:00               5.901410
# 2019-12-31 00:50:00               5.876763
# 2019-12-31 01:00:00               6.000000
# 2019-12-31 01:10:00               6.308159
# 2019-12-31 01:20:00               6.690656
# 2019-12-31 01:30:00               7.000000
# --other_condition ---
# ----results-----
# (58499, 23)
# saving file
